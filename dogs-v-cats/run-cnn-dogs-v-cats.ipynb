# %%
import os
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
from tensorflow import keras
import numpy as np

path = "test1"

#os.listdir(path)

X_test = []
id_line = []
def create_test1_data(path):
    for p in os.listdir(path):
        id_line.append(p.split(".")[0])
        img_array = cv2.imread(os.path.join(path,p),cv2.IMREAD_GRAYSCALE)
        new_img_array = cv2.resize(img_array, dsize=(80, 80))
        X_test.append(new_img_array)
create_test1_data(path)
X_test = np.array(X_test).reshape(-1,80,80,1)
X_test = X_test/255


model = keras.models.load_model('dogs-cats')
predictions = model.predict(X_test)

predicted_val = [int(round(p[0])) for p in predictions]

import pandas as pd
submission_df = pd.DataFrame({'id':id_line, 'label':predicted_val})

submission_df

submission_df[submission_df["id"]=="23"]

# %%
import os
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
from tensorflow import keras
import numpy as np
import cv2
model2 = keras.models.load_model('dogs-cats')
model1 = keras.models.load_model('../cars-v-planes/planes-cars')
model = keras.models.load_model('all')

# %%
img_array = cv2.imread("/Users/jsusser/Desktop/download-2.jpg",cv2.IMREAD_GRAYSCALE)
new_img_array = cv2.resize(img_array, dsize=(80, 80))

X_test = np.array(new_img_array).reshape(-1,80,80,1)
X_test = X_test/255
predictions = model2.predict(X_test)

predicted_val = [int(round(p[0])) for p in predictions]
    
print("This is a "+ str(predicted_val[0]))
# Out:
# This is a 0

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.figure(figsize=(20,10))
columns=7
for i in range(columns):
    plt.subplot(2,columns,i+1)
    img_array = cv2.imread("/Users/jsusser/Desktop/download-"+str(i+1)+".jpg",cv2.IMREAD_GRAYSCALE)
    new_img_array = cv2.resize(img_array, dsize=(80, 80))

    X_test = np.array(new_img_array).reshape(-1,80,80,1)
    X_test = X_test/255
    predictions = model1.predict(X_test)

    predicted_val = [int(round(p[0])) for p in predictions]
    
    if predicted_val[0] == 0:
        type = "plane"
    else:
        type = "car"
    print(predicted_val[0])
    img=mpimg.imread("/Users/jsusser/Desktop/download-"+str(i+1)+".jpg")
    imgplot=plt.imshow(img)
    plt.title("This is a "+type)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-f22fccb31233> in <module>
#       6     plt.subplot(2,columns,i+1)
#       7     img_array = cv2.imread("/Users/jsusser/Desktop/download-"+str(i+1)+".jpg",cv2.IMREAD_GRAYSCALE)
# ----> 8     new_img_array = cv2.resize(img_array, dsize=(80, 80))
#       9
#      10     X_test = np.array(new_img_array).reshape(-1,80,80,1)
#
# error: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-xi5c66nc/opencv/modules/imgproc/src/resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
i = 0
plt.figure(figsize=(20,10))
columns=7
for p in os.listdir("test1"):
    plt.subplot(2,columns,i+1)
    img_array = cv2.imread("test1/"+p,cv2.IMREAD_GRAYSCALE)
    new_img_array = cv2.resize(img_array, dsize=(80, 80))

    X_test = np.array(new_img_array).reshape(-1,80,80,1)
    X_test = X_test/255
    predictions = model2.predict(X_test)

    predicted_val = [int(round(p[0])) for p in predictions]
    
    if predicted_val[0] == 0:
        type = "cat"
    else:
        type = "dog"
    print(predicted_val[0])
    img=mpimg.imread("test1/"+p)
    imgplot=plt.imshow(img)
    plt.title("This is a "+type)
    i += 1
    if i == 7:
        break
# Out:
# 0
# 0
# 1
# 1
# 0
# 1
# 1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
i = 0
plt.figure(figsize=(20,10))
columns=7
path = "/Users/jsusser/Desktop/pc"
for p in os.listdir(path):
    if p == ".DS_Store":
        continue
    plt.subplot(1,columns,i+1)
    img_array = cv2.imread(path+"/"+p,cv2.IMREAD_GRAYSCALE)
    new_img_array = cv2.resize(img_array, dsize=(80, 80))

    X_test = np.array(new_img_array).reshape(-1,80,80,1)
    X_test = X_test/255
    predictions = model1.predict(X_test)

    predicted_val = [int(round(p[0])) for p in predictions]
    
    if predicted_val[0] == 0:
        type = "plane"
    else:
        type = "car"
    
    img=mpimg.imread(path+"/"+p)
    imgplot=plt.imshow(img)
    plt.title("This is a "+type)
    i += 1
    if i == 7:
        break
plt.show()
plt.figure(figsize=(20,10))
i = 0
path = "/Users/jsusser/Desktop/dc"
for p in os.listdir(path):
    if p == ".DS_Store":
        continue
    plt.subplot(2,columns,i+8)
    img_array = cv2.imread(path+"/"+p,cv2.IMREAD_GRAYSCALE)
    new_img_array = cv2.resize(img_array, dsize=(80, 80))

    X_test = np.array(new_img_array).reshape(-1,80,80,1)
    X_test = X_test/255
    predictions = model2.predict(X_test)

    predicted_val = [int(round(p[0])) for p in predictions]
    
    if predicted_val[0] == 0:
        type = "cat"
    else:
        type = "dog"
    
    img=mpimg.imread(path+"/"+p)
    imgplot=plt.imshow(img)
    plt.title("This is a "+type)
    i += 1
    if i == 7:
        break
plt.show()

# %%
"1 - dog, 0 - cat"
# Out:
# '1 - dog, 0 - cat'

# %%
import os
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
from tensorflow import keras
import numpy as np
import cv2
model = keras.models.load_model('all')
img_array = cv2.imread("/Users/jsusser/Desktop/download-1.jpg",cv2.IMREAD_GRAYSCALE)
new_img_array = cv2.resize(img_array, dsize=(80, 80))

X_test = np.array(new_img_array).reshape(-1,80,80,1)
X_test = X_test/255

predictions = model.predict(X_test)

predicted_val = [int(round(p[0])) for p in predictions]

predicted_val
